# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, sys
from pathlib import Path
# Add the 'modules' folder to the import path
import openai
sys.path.append(os.path.join('..', 'modules'))
import pandas as pd
pd.set_option('display.max_columns', 9000)
import utils
import gptutils
cf = utils.load_yaml_file(os.path.join('..', 'config', 'key.yaml'))
openaiclient = openai.OpenAI(
  api_key=cf['openaipivot'],  # this is also the default, it can be omitted
)
lpath=Path('../data')
#df = pd.read_excel(lpath/'sample_200_quality 2.xlsx')
df=pd.read_excel(lpath/'sample_200_quality_ass.xlsx')
df=df.iloc[:,:3]
#read only first 10 rows of the dataframe


df
# Out:
#                      key                                   2018_description  \
# 0             embrace-io  Embrace.io is a group of Los Angeles-based dat...
# 1             joget-inc-  Joget, Inc. is the developer and manager of th...
# 2                 zeto-3  Zeto is a medical technology startup transform...
# 3                baebies  Baebies is guided by a vision that every newbo...
# 4                 sifive  SiFive Coreplex IP are the most widely deploye...
# ..                   ...                                                ...
# 195  derivative-path-inc  Who We Are: Derivative Path is a San Francisco...
# 196            inpher-io  Inpher is a veteran team of entrepreneurs, cry...
# 197                 pyze  Pyze lets brands and enterprises maximize user...
# 198           green-bits  Industry Overview: \nThe legal cannabis indust...
# 199              exabeam  Exabeam is a big data security analytics compa...
#
#                                       2023_description
# ...

# %%
#This proepares a record of the prompt, adding it to a dataframe. 
#The idea is that you can then review the dataframe to make sure everythigg looks good. 
substitute = ['key','2018_description','2023_description']
prompt_file = '../prompts/pivot-v3-api-3'
model = "o4-mini-2025-04-16"
df=gptutils.prepare_prompt_dataframe(df, prompt_file, substitute,  model, print_prompt=False)

#run it on the whole dataframe
df
# Out:
#                      key                                   2018_description  \
# 0             embrace-io  Embrace.io is a group of Los Angeles-based dat...
# 1             joget-inc-  Joget, Inc. is the developer and manager of th...
# 2                 zeto-3  Zeto is a medical technology startup transform...
# 3                baebies  Baebies is guided by a vision that every newbo...
# 4                 sifive  SiFive Coreplex IP are the most widely deploye...
# ..                   ...                                                ...
# 195  derivative-path-inc  Who We Are: Derivative Path is a San Francisco...
# 196            inpher-io  Inpher is a veteran team of entrepreneurs, cry...
# 197                 pyze  Pyze lets brands and enterprises maximize user...
# 198           green-bits  Industry Overview: \nThe legal cannabis indust...
# 199              exabeam  Exabeam is a big data security analytics compa...
#
# ...

# %%
print(df['prompt'][0])
# Out:
# Evaluate the business descriptions:
#
# key: embrace-io
# 2018_description: Embrace.io is a group of Los Angeles-based data junkies who have built top-grossing apps. They are supported by mobile-focused investors, including leaders from Parse, Burstly / Testflight, MoPub, and Scopely, who are familiar with the pain of building, releasing, and running large-scale mobile apps. Since its founding less than a year ago, Embrace.io has already grown to support trillions of mobile events from many of the world’s most popular apps.
# ...

# %%
#This run all startups in the dataframe.
dftemp, response, responseall=gptutils.run_df_openai(openaiclient,df[0:2], save=True)
responseall
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 #This run all startups in the dataframe.
# ----> 2 dftemp, response, responseall=gptutils.run_df_openai(openaiclient,df[0:2], save=True)
#       3 responseall
#
# File ~/Documents/GitHub/pivot_project/notebooks/../modules/gptutils.py:166, in run_df_openai(openaiclient, df, save)
#     160 messages = [
#     161     {"role": "system", "content": "You are a helpful assistant designed to output JSON."},
#     162     {"role": "user", "content": row['prompt']},
#     163 ]
#     165 # Make sure to import or define the get_completion_json method
# --> 166 responseall, response, file = get_completion_json(openaiclient, messages, save=save, model=row['model'])
#     167 dftemp.loc[index, 'response'] = response
#     168 #df.loc[index, 'responseall'] = responseall
#
# ...

# %%
dftemp
# Out:
#           key                                   2018_description  \
# 0  embrace-io  Embrace.io is a group of Los Angeles-based dat...
# 1  joget-inc-  Joget, Inc. is the developer and manager of th...
#
#                                     2023_description  \
# 0  Embrace empowers engineers to manage the compl...
# 1  Joget, Inc is the developer of the Joget open ...
#
#                     template  \
# 0  ../prompts/pivot-v3-api-3
# 1  ../prompts/pivot-v3-api-3
#
#                                               prompt               model  \
# 0  \nEvaluate the business descriptions:\n\nkey: ...  gpt-4-1106-preview
# 1  \nEvaluate the business descriptions:\n\nkey: ...  gpt-4-1106-preview
#
#                                             response  \
# 0  {\n  "key": "embrace-io",\n  "pivot": 0,\n  "p...
# 1  {\n  "key": "joget-inc-",\n  "pivot": 0,\n  "p...
#
#                                    file
# 0  ../responses/2024-02-22_11-50-59.txt
# 1  ../responses/2024-02-22_11-51-11.txt

# %%
#This runs all of the dataframe. 
dfnew, response, responseall=gptutils.run_df_openai(openaiclient,df, save=True)
# save df new to a pickle file
dfnew.to_pickle(lpath/'dfnew.pkl')

# %%
example={'key': 'key',
'pivot': 0,
'probability_pivot': 0,
'justification': "justification",
'zoom-in_pivot': 0,
'zoom-out_pivot': 0,
'customer_segment_pivot': 0,
'customer_needs_pivot': 0,
'platform_pivot': 0,
'business_architecture_pivot': 0,
'value_capture_pivot': 0,
'engine_of_growth_pivot': 0,
'channel pivot': 0,
'technology_pivot': 0}

dfnew2 = dfnew.apply(gptutils.process_json, ex=example, axis=1)

# %%
# save dfnew2 to a csv file
dfnew2.to_pickle('../data/sample_200_pivot.pkl')
dfnew2.to_csv('../data/sample_200_pivot.csv', index=False)
dfnew2.to_excel('../data/sample_200_pivot.xlsx', engine='xlsxwriter')
